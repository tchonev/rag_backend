# %%
import fitz as PyMuPDF
import json
import os
import psycopg2
from pathlib import Path
from datetime import datetime
import re
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
import numpy as np
import pandas as pd
import re
import time

# %%
load_dotenv()
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")
DB_PORT = os.getenv("DB_PORT")
DB_CONNECTION = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
PDF_FOLDER = Path.home() / "Downloads" / "domaindata" # Update this path
METADATA_FILE = Path.home() / "Downloads" / "domaindata" / "metadata.jsonl"
MODEL_NAME = 'all-MiniLM-L6-v2'  # Good balance of speed and quality
BATCH_SIZE = 64  # Increase if you have more RAM

# %%
# Create the table. We'll add the vector column later because it depends on model embedding dimension
conn = psycopg2.connect(DB_CONNECTION)
cur = conn.cursor()
cur.execute("""
    CREATE TABLE IF NOT EXISTS document_chunks (
        id SERIAL PRIMARY KEY,
        uuid UUID,
        title TEXT,
        content TEXT,
        chunk_index INTEGER,
        page_numbers TEXT,
        industries TEXT[],
        date TIMESTAMP,
        country_codes TEXT[],
        chunk_length INTEGER,
        created_at TIMESTAMP DEFAULT NOW()
    );""")
    
conn.commit()
cur.close()
conn.close()
print("✓ Database table created/verified")
# Out:
# ✓ Database table created/verified

# %%
def extract_pdf_text(pdf_path):
    """Extract text from PDF file with page tracking"""
    try:
        doc = PyMuPDF.open(pdf_path)
        pages_data = []
        
        for page_num, page in enumerate(doc):
            page_text = page.get_text().strip()
            if page_text:  # Only keep non-empty pages
                pages_data.append({
                    'page_num': page_num + 1,
                    'text': page_text
                })
        
        doc.close()
        return pages_data
    except Exception as e:
        print(f"Error processing {pdf_path}: {e}")
        return None

# %%
import re

def _clean_pdf_text(txt: str) -> str:
    # Minimal cleanup: remove soft hyphens, fix hyphenated line breaks, normalize spaces
    txt = txt.replace('\u00ad', '')                                # soft hyphen
    txt = re.sub(r'(\w)-\s*\n\s*(\w)', r'\1\2', txt)               # hyphenated line breaks
    txt = txt.replace('\r', ' ').replace('\n', ' ')                # newlines -> space
    txt = re.sub(r'\s+', ' ', txt).strip()                         # collapse spaces
    return txt


# Helper to find a nice end near target
def pick_end(lo, tgt, hi, text):
    """Find a good cut position in text between lo..hi, aiming near tgt."""
    sent_re = re.compile(r'[\.!\?…][\"»’”\)\]]*\s')
    # forward first
    m = sent_re.search(text, tgt, hi)
    if m: return m.end()
    # backward
    last = -1
    for m in sent_re.finditer(text, lo, tgt):
        last = m.end()
    if last != -1: return last
    # whitespace
    ws_back = text.rfind(' ', lo, tgt)
    if ws_back != -1: return ws_back + 1
    ws_fwd = text.find(' ', tgt, hi)
    if ws_fwd != -1: return ws_fwd + 1
    return tgt

    
def chunk_text(pages_data, chunk_size=1200, overlap=180, min_chunk=80):
    # 1) Build full_text and track page spans (char ranges)
    full_text = ""
    page_positions = {}
    cur = 0
    for p in pages_data:
        t = _clean_pdf_text(str(p.get("text", "")))
        if not t:
            continue
        wrapped = f" {t} "
        start = cur
        full_text += wrapped
        cur += len(wrapped)
        page_positions[int(p["page_num"])] = (start, cur)

    if not full_text.strip():
        return []

    n = len(full_text)
    chunks, idx = [], 0
    start = 0

    while start < n:
        tgt = min(start + chunk_size, n)
        lo  = max(start + max(0, chunk_size - 200), start)  # look ~200 chars back
        hi  = min(tgt + 200, n)                             # and ~200 ahead
        end = pick_end(lo, tgt, hi, full_text)

        piece = full_text[start:end].strip()
        if end < n and len(piece) < min_chunk:
            # try to extend a bit to avoid tiny fragments
            hi2 = min(end + (min_chunk - len(piece)) + 120, n)
            end = pick_end(end, end, hi2)
            piece = full_text[start:end].strip()

        if piece:
            # pages spanned by this chunk
            chunk_pages = [str(p) for p, (ps, pe) in page_positions.items()
                           if not (end <= ps or start >= pe)]
            chunks.append({
                "text": piece,
                "chunk_index": idx,
                "pages": ",".join(chunk_pages),
                "length": len(piece)
            })
            idx += 1

        if end >= n:
            break

        # next start with overlap, but nudge to next word boundary
        raw_next = max(0, end - overlap)
        # if we’re in the middle of a word, move forward to the next space
        j = raw_next
        while j < n and not full_text[j].isspace():
            j += 1
        # skip consecutive spaces
        while j < n and full_text[j].isspace():
            j += 1
        start = min(j, n)

    return chunks

# %%
metadata = {}
missing_count = 0
with open(METADATA_FILE, 'r') as f:
    print("Loading metadata...")
    for line_num, line in enumerate(f, 1):
        if line.strip():
            try:
                data = json.loads(line)
                metadata[data['uuid']] = data
            except json.JSONDecodeError as e:
                print(f"JSON error on line {line_num}: {e}")
    print(f"✓ Loaded metadata for {len(metadata)} documents")
# Out:
# Loading metadata...
# ✓ Loaded metadata for 500 documents

# %%
pdf_files = list(Path(PDF_FOLDER).glob("*.pdf"))
print(f"✓ Found {len(pdf_files)} PDF files")

processed = 0
failed = 0
total_chunks = 0

# Connect to database
conn = psycopg2.connect(DB_CONNECTION)
cur = conn.cursor()

for pdf_file in pdf_files:
    try:
        # Extract UUID from filename
        file_uuid = pdf_file.stem
        
        # Get metadata if available, otherwise use defaults
        if file_uuid in metadata:
            meta = metadata[file_uuid]
            title = meta.get('title', pdf_file.name)
            industries = meta.get('industries', [])
            date = meta.get('date')
            country_codes = meta.get('country_codes', [])
        else:
            # Use filename as fallback
            meta = {}
            title = pdf_file.name
            industries = []
            date = None
            country_codes = []
            no_metadata_count += 1
        
        # Extract text
        pages_data = extract_pdf_text(pdf_file)
        if not pages_data:
            failed += 1
            continue
        
        # Create chunks
        chunks = chunk_text(pages_data)
        
        # Store chunks in database
        for chunk in chunks:
            cur.execute("""
                INSERT INTO document_chunks 
                (uuid, title, content, chunk_index, page_numbers, 
                 industries, date, country_codes, chunk_length)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
            """, (
                file_uuid,
                meta.get('title', ''),
                chunk['text'],
                chunk['chunk_index'],
                chunk['pages'],
                meta.get('industries', []),
                meta.get('date'),
                meta.get('country_codes', []),
                chunk['length']
            ))
        
        total_chunks += len(chunks)
        processed += 1
        
        if processed % 100 == 0:
            conn.commit()
            print(f"  Processed {processed} files, {total_chunks} chunks so far...")
        
    except Exception as e:
        print(f"✗ Error processing {pdf_file.name}: {e}")
        failed += 1

# Final commit
conn.commit()
cur.close()
conn.close()

print(f"\n{'='*60}")
print(f"Processing complete!")
print(f"✓ Successfully processed: {processed} files")
print(f"✗ Failed: {failed} files")
print(f"📄 Total chunks created: {total_chunks}")
print(f"📊 Average chunks per file: {total_chunks/processed if processed > 0 else 0:.1f}")
# Out:
# ✓ Found 499 PDF files
# Processing: Topcon Investor presentation...
# Processing: Gross Domestic Product by State and Personal Incom...
# Processing: Irisity Analyst report...
# Processing: Saudi Cement Sector Monthly Report October 2024...
# Processing: Country Analysis Brief Egypt...
# Processing: Empowering Women Through Solar Energy A Case Study...
# Processing: Inflation Updated Through August 2024 Regional...
# Processing: JGC Investor presentation...
# Processing: Ukraine From War to Peace and Recovery...
# Processing: Seasonal Summary Crop Report...
# Processing: Energy Private Limited Company report...
# Processing: Türkiye A Mild Recession as of 3Q24...
# Processing: Rhodium Climate Outlook ETSAP Workshop...
# Processing: Latin America Corporate Payment Survey 2024...
# Processing: Peyto Exploration & Development Analyst report...
# Processing: Bridging the Gap Helping Acquirers Meet Evolving M...
# Processing: Johnson Controls Quarterly report...
# Processing: SunStream Quarterly report...
# Processing: BHP Is Lagging Its Peers On Scope 3 And Steel Tech...
# Processing: Distress Indices Analysis Report...
# Processing: Monthly Gold Monitor...
# Processing: Equifax Quarterly report...
# Processing: CPB World Trade Monitor July 2024...
# Processing: CCPI Based Headline Inflation Continued to Remain ...
# Processing: Quarterly Financial Report U S Manufacturing Minin...
# Processing: Housing Stock in Kent...
# Processing: National Payments Corporation of India Analyst rep...
# Processing: Life Holdings, Inc Investor presentation...
# Processing: Forrestania Company report...
# Processing: Universal Partners Limited Half year report...
# Processing: Press Release on Consumer Price Index Numbers for ...
# Processing: OVB Investor presentation...
# Processing: Monthly Investment Views...
# Processing: Respiratory Diseases Statistics...
# Processing: Hindustan Unilever Ltd Q4FY24 Result Update...
# Processing: Hypo Quarterly report...
# Processing: IB Group Company report...
# Processing: State of the Market...
# Processing: Dollarama Investor presentation...
# Processing: Gross Domestic Product Income and Expenditure Thir...
# Processing: Groww Company report...
# Processing: Press Release...
# Processing: Zim Integrated Shipping Services, Ltd. Investor pr...
# Processing: The Use of Information and Communication Technolog...
# Processing: South African Companies Investor presentation...
# Processing: What Does Consistent Participation in 401 k Plans ...
# Processing: IESO Strategic Advisory Committee...
# Processing: Energy Connectivity for Sustainable Development in...
# Processing: Steven C.M. Wong Assistant Director General ISIS M...
# Processing: The Weaponization Of Money Risks Of Global Financi...
# Processing: Socio Economic Development of the Republic of Kaza...
# Processing: MSCI Emerging Markets Growth Index USD...
# Processing: Predictions 2025 MENA Edition...
# Processing: KDDI Investor presentation...
# Processing: At A Glance Annual Review 2024...
# Processing: Predictions 2025 Ivory Coast Edition...
# Processing: Investec Bank Quarterly report...
# Processing: Economic Evidence to the Pay Review Bodies 2025 26...
# Processing: Melbourne Institute Phases of the Australian Busin...
# Processing: Climate Peace and Security Fact Sheet Colombia...
# Processing: From the Trading Floor...
# Processing: February 2025 Revenue Estimate...
# Processing: Report Name:...
# Processing: Policy Complexity...
# Processing: Hazardous Waste Europe Investor presentation...
# Processing: Nokian Tyres Half year report...
# Processing: Indonesia s Bond Market Analysis...
# Processing: Natural Gas Industry in France...
# Processing: Economic Footprint of the Pharmaceutical Industry ...
# Processing: International Tractors Ltd. Company report...
# Processing: Treasurer s Investments January 2025...
# Processing: Ringgit Becomes Top Performing Currency Benefiting...
# Processing: Week in Review 30 August 2024...
# Processing: Canada Fact Sheet...
# Processing: Russell US Indexes Moving to a Semi Annual Index R...
# Processing: Indofil Industries Company report...
# Processing: How Would Tariffs Affect The Markets...
# Processing: Wealth Management Industry in the US...
# Processing: Top 10 Risks in Telecommunications...
# Processing: Monthly Economic Review August 2024...
# Processing: May to July 2025 Outlook Perspective for the Lower...
# Processing: Livestock Weighted Average Report For 3 17 2025 Fi...
# Processing: Automotive Industry Monthly Report November 2024...
# Processing: Gross Domestic Product 4th Quarter and Year 2024 A...
# Processing: Finding New Directions for Growth Growing Sales fo...
# Processing: Borosil Analyst report...
# Processing: Metso Investor presentation...
# Processing: International Merchandise Trade...
# Processing: CONSUMER PRICE INDEX DECEMBER 2024...
# Processing: 2025 World Economic Outlook The World Faces Trump ...
# Processing: ECTRIMS Investor presentation...
# Processing: Navin Fluorine International Limited Analyst repor...
# Processing: The Potential Of The Fourth Industrial Revolution ...
# Processing: Effective Prevention of Child Maltreatment...
# Processing: Quarterly Energy Prices...
# Processing: Infosys Bank Tech Index Volume 3 August 2024...
# Processing: Quarterly Gas Market Review: Asia market drives pr...
# Processing: Monroe Capital Half year report...
# Processing: FTSE Global Equity High Income Index Series...
# Processing: 2020 2021 Minerals Yearbook Oman Advance Release...
#   Processed 100 files, 2510 chunks so far...
# Processing: Detailed SA Vehicle Sales Figures for August 2024...
# Processing: Financial Market Inflation Expectations 9 2024...
# Processing: 2024 Was Another Exceptional Year for Investors...
# Processing: Apple in Payments...
# Processing: Global Critical Minerals Outlook 2024...
# Processing: Tallying Tariffs Growth Gaps Bruised Budgets Soft ...
# Processing: Markley Investor presentation...
# Processing: Strategic Analysis Adaptation Assessment...
# Processing: Monitoring the German Bioeconomy Summary...
# Processing: Invasive Group A Streptococcal iGAS Disease in Ont...
# Processing: Forex Economics and Strategy...
# Processing: Everest Group Finance And Accounting Outsourcing F...
# Processing: Premier Insurance Limited Company report...
# Processing: Cementir Analyst report...
# Processing: Chimerica Consciously Uncouples...
# Processing: Graph LLMs AI s Next Frontier in Banking and Insur...
# Processing: Europe CRE 180 Economic Outlook Real Estate Perspe...
# Processing: Panasonic Quarterly report...
# Processing: UBS Investor presentation...
# Processing: Antero Resources Quarterly report...
# Processing: United Breweries Analyst report...
# Processing: Weekly Macro Views WMV...
# Processing: Gross Domestic Product by Economic Activity...
# Processing: Datalogic Analyst report...
# Processing: Market Outlook...
# Processing: Community Eligibility The Key to Hunger Free Schoo...
# Processing: Northwest Syria Humanitarian Dashboard Jan Sep 202...
# Processing: Macroeconomic Trends in the British German Corrido...
# Processing: Breuninger Investor presentation...
# Processing: Fresenius Helios Quarterly report...
# Processing: Grain Market Outlook September 2024...
# Processing: Asia s Shipbuilding Renaissance Record Orders and ...
# Processing: Crédit Mutuel Company report...
# Processing: Olefins Derivatives Intratec Primary Commodity Pri...
# Processing: Bharti Telecom Ltd. Analyst report...
# Processing: FAUJI FERTILIZER Company report...
# Processing: PGE EDAM Overview...
# Processing: The Energy Transition Where Are We Really...
# Processing: Ageas Investor presentation...
# Processing: Listed Company Action Status...
# Processing: Wipro Quarterly report...
# Processing: Eutelsat Investor presentation...
# Processing: South West Port Limited Company report...
# Processing: Patient Care Disciplinary Case Processing Times wi...
# Processing: National Animal By Product Feedstuff Report...
# Processing: Road Accidents Year 2023...
# Processing: Saudi Arabian Amiantit Annual report...
# Processing: REIT fund Half year report...
# Processing: ASTRAL Analyst report...
# Processing: Direct Line Insurance Group Analyst report...
# Processing: Umicore Investor presentation...
# Processing: Quarterly Percentage of Children in NSW Fully Immu...
# Processing: Economy WRAP...
# Processing: Livestock Weighted Average Report for 2 11 2025 Fi...
# Processing: 2024 Shunto The First Wage Increase Above 5 Since ...
# Processing: PowerGrid Analyst report...
# Processing: H1 2024 Investment Banking and Global Markets Upda...
# Processing: Euro Wrap Up...
# Processing: International Air Arrivals 2023 2024 Report...
# Processing: FTSE World Government Bond Index 2024 Performance ...
# Processing: Eurozone Japan Navigating Tariff Headwinds...
# Processing: 19C Sheep Surveys 2024 Memorandum...
# Processing: Czechia In The World And In The EU...
# Processing: Early Stage Startup Index 2024...
# Processing: Enhanced Surveillance of Clostridioides Clostridiu...
# Processing: Households Statistics on Financial Assets and Liab...
# Processing: Oceania Fact Sheet...
# Processing: August 2024 New Products...
# Processing: EU Olive Oil Production Update 2024...
# Processing: Monthly Market Roundup Covering September 2024...
# Processing: Food Industries Ltd Company report...
# Processing: The Business Value of VMware vSAN Storage for Hype...
# Processing: V2G Electricity Market Modelling Report...
# Processing: Y M Monthly Production And Sales Data Including Qt...
# Processing: Philips Investor presentation...
# Processing: Mapping the FinTech Innovation Landscape in India...
# Processing: BRITISH AMERICAN TOBACCO PLC...
# Processing: South Korea IP Inexplicably Dropped in September Y...
# Processing: Monetary Policy Report Condensed Version August 20...
# Processing: Soybeans Grain Market Outlook January 2025...
# Processing: Youth Integration in the EU Navigating Digitalisat...
# Processing: Albemarle Investor presentation...
# Processing: Retail Media 2 0...
# Processing: UOB House View 3Q 2024...
# Processing: GMM Pfaudler Limited Company report...
# Processing: Orange County...
# Processing: US Imported Beef Market A Weekly Update...
# Processing: OCC Mortgage Metrics Report...
# Processing: Synergies AA6 Labour and Cost Escalation Forecast...
# Processing: A quiet year for listings, with headwinds remainin...
# Processing: Henkel Company report...
# Processing: India s Gold Market Update...
# Processing: Platinum Perspectives Trump s Policies and the PGM...
# Processing: Nestlé Investor presentation...
# Processing: The Global Productivity Challenge Understanding Tr...
# Processing: FTI Consulting Investor presentation...
# Processing: Uncommon Truths 2024 A Year in Review...
# Processing: Weekly Shipping Market Report Week 47...
# Processing: Max Healthcare Analyst report...
# Processing: Dynasty Fine Wines Group Limited Annual report...
#   Processed 200 files, 5026 chunks so far...
# Processing: Konami Quarterly report...
# Processing: UniCharm Corporation Investor presentation...
# Processing: Bajaj Finance Investor presentation...
# Processing: Hot Core Inflation Tariffs Should Keep the BoC on ...
# Processing: Fixed Income Insights...
# Processing: You Can Run But You Can t Hedge...
# Processing: Florida Citrus Production December Forecast...
# Processing: Hair Care Business Growth Strategy...
# Processing: MSCI World Screened Index USD...
# Processing: Epidemiological Report for Respiratory Illnesses...
# Processing: Digital Assets in Central Asia and the Caucasus...
# Processing: APL Apollo Tubes Analyst report...
# Processing: Statistical Country Profile Tanzania United Republ...
# Processing: COVID 19 Associated Hospitalizations Among U S Adu...
# Processing: Precision Equipment Business Investor presentation...
# Processing: Dairy Cattle and Milk Production...
# Processing: Asset Tokenization in Capital Markets A Primer...
# Processing: Yellowfin Tuna YFN Nov 2024...
# Processing: Health Care Workforce Census Licensed Practical Nu...
# Processing: Vaccine Preventable Disease Surveillance Report...
# Processing: The Siam Cement Public Company Limited Quarterly r...
# Processing: Monthly Macro Strategy...
# Processing: Agility in volatility: Rebalancing CRO priorities ...
# Processing: Hong Kong SAR Monthly...
# Processing: India Australia Economic Cooperation...
# Processing: Table of Contents...
# Processing: F.I.L.A. Group Analyst report...
# Processing: Comparison of the fast-charging capability of elec...
# Processing: Ipsos Global Trustworthiness Index 2024...
# Processing: Piramal Enterprises Analyst report...
# Processing: MSCI EMU Select Factor Mix Index EUR...
# Processing: Personal Consumption Expenditures by State 2023...
# Processing: Health Equity Confidential Feedback Reports Execut...
# Processing: External Sector Performance September 2024...
# Processing: Statewide Substance Use Disorder SUD Prevalence an...
# Processing: Allied Digital Services Ltd Investor presentation...
# Processing: Australia Stone Fruit Annual...
# Processing: Manorama Industries Company report...
# Processing: Detailed Analysis of Secondary Data...
# Processing: The Islamic Republic Of Iran s Chastity And Hijab ...
# Processing: OECD Interim Economic Outlook Turning the Corner...
# Processing: New Passenger Car Registrations Increase by 5 6 in...
# Processing: Interest Rates Monthly...
# Processing: Manufacturing Ltd Company report...
# Processing: Growthpoint Properties Investor presentation...
# Processing: BVB Group Investor presentation...
# Error processing /home/chonata/Downloads/domaindata/6abc0b58-ca4d-4311-94a2-3272901685c3.pdf: Cannot open empty file: filename='/home/chonata/Downloads/domaindata/6abc0b58-ca4d-4311-94a2-3272901685c3.pdf'.
# Processing: The Transformative Potential of the GCC Culture an...
# Processing: FINA Pre Budget Submission 2025...
# Processing: Industrial Metals Monthly Iron Ore Tumbles Below 9...
# Processing: South Korea Wine Market Report...
# Processing: Winning The Game August 26 2024 Webinar...
# Processing: IEEJ Outlook 2025...
# Processing: Daily Report...
# Processing: Treasury Gains Support ROA Stability for Banks in ...
# Processing: EDB Continues To Secure High Quality Investments A...
# Processing: Alibaba Investor presentation...
# Processing: Ferrexpo Investor presentation...
# Processing: Growth Catch Up...
# Processing: Food Service Hotel Restaurant Institutional Annual...
# Processing: Iowa Direct Hay Report...
# Processing: Weekly Respiratory Disease Surveillance Report...
# Processing: Progress Toward Poliomyelitis Eradication Pakistan...
# Processing: ECB Publishes Supervisory Banking Statistics on Si...
# Processing: Sonata Software Analyst report...
# Processing: Quarterly Residential Vacancies and Homeownership ...
# Processing: Kesko Investor presentation...
# Processing: Deposits Interest Rates for Individual Customers i...
# Processing: How Can Central Eastern and Southeastern Europe Wi...
# Processing: 2022 Map Atlas Pancreatic Cancer...
# Processing: Capgemini Financial Services Top Trends 2025 Life ...
# Processing: Cape Winelands A Leading Regional Economy...
# Processing: Xinjiang cotton still haunts global supply chains,...
# Processing: Credit Derivatives Trading Activity Reported in EU...
# Processing: Santhoshimathaa Edible Oils Refinery Private Limit...
# Processing: Axis Securities Company report...
# Processing: Supplementary Information For six months ended 31 ...
# Processing: Navin Fluorine International Analyst report...
# Processing: NSG Investor presentation...
# Processing: Fund Flow Report...
# Processing: A Well of Opportunities...
# Processing: Oil And Gas Market in the US...
# Processing: Lifewear A New Industry Briefing Session...
# Processing: Consumer and Firm Perceptions of the Aggregate Lab...
# Processing: GDP and the Economy Third Estimates for the Third ...
# Processing: Ipsen Investor presentation...
# Processing: Munich Office Q1 2023 Market Report...
# Processing: GeoDisruption³ Balancing Gigawatts Gigabytes and G...
# Processing: Economic Outlook Conference Bluegrass Area Housing...
# Processing: Trade Friction Clouds an Already Bearish Soybean M...
# Processing: 2020 2021 Minerals Yearbook Singapore Advance Rele...
# Processing: MAPFRE Company report...
# Processing: Arvind Investor presentation...
# Processing: Utility Scale Solar 2024 Edition...
# Processing: Department of Market Monitoring Report...
# Processing: Sapporo Holdings Ltd Quarterly report...
# Processing: Indian Banking Sector Analyst report...
# Processing: TRF Limited Company report...
# Processing: Otsuka Corporation Investor presentation...
# Processing: Integrating Electric Vehicles Into The Grid...
# Processing: Myanmar Logistics Briefing Quarterly Update...
# Processing: Sansera Analyst report...
# Processing: Herbalife Quarterly report...
# Processing: N R Agarwal Industries Limited Company report...
#   Processed 300 files, 7405 chunks so far...
# Processing: BMW Industries Limited Investor presentation...
# Processing: Quarterly Survey of Business Opinions and Expectat...
# Processing: American Woodcock Population Status 2024...
# Processing: Sify Technologies Company report...
# Processing: Market Trends For Week Ending December 20 2024...
# Processing: ITC Company report...
# Processing: Presentation to the Portfolio Committee on Agricul...
# Processing: Forecasts For Europe...
# Processing: Financial Results of Non Financial Enterprises for...
# Processing: Vision Insights Australia Traveler Profiles H1 202...
# Processing: FEEDER CATTLE...
# Processing: Washington Strategy Tariffs and Commodity Impact...
# Processing: Groupama Group Company report...
# Processing: Surveying the Post Election Landscape...
# Processing: Water Solutions Ambition to Double Revenue...
# Processing: Industry To Industry Payment Flows UK 2017 To 2024...
# Processing: Value Focus FinTech Industry First Quarter 2015...
# Processing: The Evolution Of Labor Supply In Egypt Current And...
# Processing: ADEKA Quarterly report...
# Processing: Weekly Petrol Prices Report...
# Processing: M&A Advisor Investor presentation...
# Processing: Vale Analyst report...
# Processing: Enerfin Investor presentation...
# Processing: Producer Price Inflation UK October 2024...
# Processing: Invasive Group A Streptococcal iGAS Disease in Ont...
# Processing: The 2024 U S Presidential Election Scenarios and S...
# Processing: 5 Things to Know From KKR s 2025 Outlook...
# Processing: Trade and Investment Factsheets...
# Processing: Weekly System Status Report 2024 Week 10 04 03 202...
# Processing: IHI Annual report...
# Processing: Sekisui House Investor presentation...
# Processing: Paytm Analyst report...
# Processing: Australian Payments Surcharging a Total Mess...
# Processing: The Budget Execution Report for the Financial Year...
# Processing: Airbus Quarterly report...
# Processing: West Coast Economic Overview September 2024...
# Processing: Green Group Half year report...
# Processing: 2025 State Of The Industry Report...
# Processing: Electric Vehicle Efficiency Unlocking Consumer Sav...
# Processing: Delivering a Voluntary Scheme for Health and Growt...
# Processing: Carborundum Universal Company report...
# Processing: September Monthly Farm Report...
# Processing: Press Release Economic Performance in Third Quarte...
# Processing: Economic Activity and Social Change in the UK Real...
# Processing: Examining the Macroeconomic Costs of Occupational ...
# Processing: Torii Pharmaceutical Company report...
# Processing: Smallest Sunflower Crop in a Decade to Severely Im...
# Processing: Export Sales Audit Summary for Week Ending 08 22 2...
# Processing: Sweden s Climate Action Strategy...
# Processing: Monthly Communicable Disease Report Dengue Virus I...
# Processing: Dunkelflaute: Driving Europe Gas Demand Volatility...
# Processing: Benefit Claimants in Kent...
# Processing: California s Nurse Practitioner Workforce Understa...
# Processing: The Connection...
# Processing: Morning Market Commentary...
# Processing: AIA Company report...
# Processing: Silver Lake Resources Investor presentation...
# Processing: De Beers Analyst report...
# Processing: Fidelity Global Monthly High Income ETF Fund...
# Processing: Building Permits July 2024...
# Processing: November Inflation Stood at 5 2 in Line with Expec...
# Processing: Dongre Company report...
# Processing: The 2024 U S Presidential Race Four Weeks Out Upda...
# Processing: Market Snapshot Beef Sheepmeat Australia...
# Processing: Credit Risk Unveiled Trends Technologies and Trans...
# Processing: PwC Guyana Investor presentation...
# Processing: Empire Industries Company report...
# Processing: Ammo India 2024...
# Processing: CPI Based Headline Inflation Continued To Remain I...
# Processing: Digital Assets Evolution and Correlations with Oth...
# Processing: The US 2 8 Trillion Opportunity How Better Health ...
# Processing: Sarabhai Investor presentation...
# Processing: Transport Corporation of India Company report...
# Processing: Consensus Forming for BOJ s QT Anticipate Yield Cu...
# Processing: Asian Paints Ltd Q3FY25 Result Update...
# Processing: Daily Fixed Income Insights...
# Processing: Table of Commissions and Charges...
# Processing: Now decides next:...
# Processing: The EU Potato Sector Statistics on Production Pric...
# Processing: Sector Equity Compass Beyond the Inauguration...
# Processing: 2025 Aviation Industry Review and Outlook...
# Processing: CP All Annual report...
# Processing: Monthly Climate and Weather...
# Processing: Enhancing Agricultural Research and Development fo...
# Processing: Understanding the Journey to Full Employment...
# Processing: 20 Metropolitan Areas with Highest Rates of House ...
# Processing: Kesko s Sales in September...
# Processing: Human Capital Formation in the Caribbean Implicati...
# Processing: Livestock and Products Market Update...
# Processing: Financial Stability Review November 2024...
# Processing: Report on Monthly Survey on the Business Situation...
# Processing: Natera Investor presentation...
# Processing: HIGH STREET SALES TRACKER...
# Processing: Tritax Eurobox Investor presentation...
# Processing: Quarterly Retail E Commerce Sales 3rd Quarter 2024...
# Processing: IND AAA Analyst report...
# Processing: Oecd Economic Outlook Volume 2024 Issue 2...
# Processing: SAMHI Hotels Ltd Analyst report...
# Processing: Berks County WDA Profile...
# Processing: Regional Labour Market Forecasts...
#   Processed 400 files, 10033 chunks so far...
# Processing: Ausplay Survey Advancements Detailed Information A...
# Processing: Eudis HEDI DIANA What s Behind Three Defense Innov...
# Processing: Country Analysis Brief Saudi Arabia...
# Processing: Consolidated Zonal Economic Performance Report for...
# Processing: Neiti Independent Administrator IA Presentation...
# Processing: Testimony to the House Committee on Education and ...
# Processing: Trust in Professions...
# Processing: MGM Resorts International Analyst report...
# Processing: Lithium Deposits of Nevada...
# Processing: Economic and Monetary Conditions...
# Processing: Stanbic Investor presentation...
# Processing: The Use of Derivatives on CO₂ Emission Allowances ...
# Processing: Understanding Employment and Shocks in Ethiopia 19...
# Processing: Quarterly Energy Prices...
# Processing: Shipping Co Investor presentation...
# Processing: PwC Quarterly Economic Digest Q4 2024...
# Processing: Piramal Enterprises Analyst report...
# Processing: Achievement of the 2 Percent Price Stability Targe...
# Processing: Florida Arbovirus Surveillance Week 4 January 19 2...
# Processing: Meiji Quarterly report...
# Processing: Press Release KASE Presents the Performance of the...
# Processing: Standard Chartered Quarterly report...
# Processing: NanoXplore Quarterly report...
# Processing: Main Developments in Money Markets and ECB Policy ...
# Processing: 2019 Minerals Yearbook Gypsum Advance Release...
# Processing: Case Processing Performance Analysis...
# Processing: Medical Services CFC Monthly Monitoring Report...
# Processing: CNB s New Forecast Monetary Policy Report Winter 2...
# Processing: CFS Divisia Monetary Data For The United States Au...
# Processing: PE Pulse 2025...
# Processing: Consumers Price Index Review 2024...
# Processing: AIB Ireland Manufacturing PMI Sharpest Decline in ...
# Processing: Cotton This Month...
# Processing: Press Release CCPI Based Headline Inflation Decele...
# Processing: Bank Watch...
# Processing: SBI Life Insurance Company report...
# Processing: Petronas Chemicals Analyst report...
# Processing: Longevity and the Public Purse...
# Processing: Eurex EnLight Investor presentation...
# Processing: HVRP Quarterly Performance Report Desk Guide...
# Processing: Country Energy Report Sweden...
# Processing: Emerging Market Debt Market Commentary Q3 2024...
# Processing: Semiconductor Market Insights Discover the Benefit...
# Processing: January 2025 Data Release...
# Processing: Water To Wire Heating Homes With Hydro...
# Processing: Unisys Quarterly report...
# Processing: SoftBank Quarterly report...
# Processing: YTL Half year report...
# Processing: NSW Respiratory Surveillance Report Week Ending 28...
# Processing: HAMBORNER Investor presentation...
# Processing: Emirates Company report...
# Processing: Sustainable Aviation Fuel A Life Flight for the Et...
# Processing: Household Savings In Sweden...
# Processing: July Macro Brief Normalizing Labor Markets...
# Processing: Euro Wrap Up...
# Processing: Reducing College Costs for Low Income Students Tec...
# Processing: Manufacturing Overview CY2024 Q3...
# Processing: Ambow Education Company report...
# Processing: Oil and Gas...
# Processing: Retail Foods Annual...
# Processing: Market Review and Outlook for Irish Poultry...
# Processing: 2024 Hospital Nurse Staffing Study Characteristics...
# Processing: Rocket Lab Quarterly report...
# Processing: Agriculture and Climate Resilience Constraints and...
# Processing: Preliminary Course Enrollment and Revenue Activity...
# Processing: Evaluation of HF 4211 SF 4089 Coverage for Vasecto...
# Error processing /home/chonata/Downloads/domaindata/cc1ead3b-9828-407d-8635-cb7d372e0bb6.pdf: Failed to open file '/home/chonata/Downloads/domaindata/cc1ead3b-9828-407d-8635-cb7d372e0bb6.pdf'.
# Processing: Zydus Analyst report...
# Processing: Equifax Company report...
# Processing: 2024 Iowa State University Land Value Survey Overv...
# Processing: Ashima Limited Investor presentation...
# Processing: NZ GDP Q3 2024 Review...
# Processing: RES to Green Hard to Abate Sectors...
# Processing: Impact of COVID 19 on Food Security and Cropping P...
# Processing: SUPPLEMENTARY MATERIAL...
# Processing: Retail Insights 2024 Delivering More Than You Barg...
# Processing: Clean Investment Monitor Q4 2024 Update...
# Processing: Weekly Report...
# Processing: Mission Accomplished for 2024 as Strong 4Q Pushes ...
# Processing: Energy Sufficiency in the EU A Selection of Indica...
# Processing: Hospitality Market Monitor...
# Processing: Stone Fruit Annual...
# Processing: Borealis PE X Pipe Solutions...
# Processing: Doyon Investor presentation...
# Processing: Banxico Is Set to Keep Cutting Rates Amid Cooling ...
# Processing: Index Of Industrial Production IIP For April June ...
# Processing: Ahead CMS Designed Medicare Fee for Service FFS Ho...
# Processing: Japan s Economic Warfare in the 1930s and Early 19...
# Processing: Communicable Disease Threats Report...
# Processing: Marico Company report...
# Processing: HBM Partners Investor presentation...
# Processing: Event Report Hybrid Seminar Circularity And Used T...
# Processing: SRLEV NV Quarterly report...
# Processing: Realtors Confidence Index Survey...
# Processing: Measuring Participation in Adult Learning New Targ...
# Processing: Bristol-Myers Squibb Quarterly report...
# Processing: Semi Solid State Battery Technology Driving the De...
#
# ============================================================
# Processing complete!
# ✓ Successfully processed: 495 files
# ✗ Failed: 4 files
# 📄 Total chunks created: 12452
# 📊 Average chunks per file: 25.2

# %%
model = SentenceTransformer(MODEL_NAME)
embedding_dim = model.get_sentence_embedding_dimension()
print(f"✅ Model loaded! Embedding dimension: {embedding_dim}")
# Out:
# ✅ Model loaded! Embedding dimension: 384

# %%
# Add vector column to the database 
conn = psycopg2.connect(DB_CONNECTION)
cur = conn.cursor()

try:
    # Add embedding column
    cur.execute(f"""
        ALTER TABLE document_chunks 
        ADD COLUMN IF NOT EXISTS embedding vector({embedding_dim})
    """)
    print(f"✅ Added embedding column (dimension: {embedding_dim})")
    
    # Create index for faster similarity search
    cur.execute("""
        CREATE INDEX IF NOT EXISTS embedding_cosine_idx 
        ON document_chunks USING ivfflat (embedding vector_cosine_ops) 
        WITH (lists = 20)
    """)
    print("✅ Created vector similarity index")
    
    conn.commit()
    
except Exception as e:
    print(f"Note: {e}")
    # Index creation might fail on empty table, that's OK
    
finally:
    cur.close()
    conn.close()
# Out:
# ✅ Added embedding column (dimension: 384)
# ✅ Created vector similarity index

# %%
def check_status():
    """Check how many chunks need embeddings"""
    conn = psycopg2.connect(DB_CONNECTION)
    cur = conn.cursor()
    
    cur.execute("SELECT COUNT(*) FROM document_chunks")
    total_chunks = cur.fetchone()[0]
    
    cur.execute("SELECT COUNT(*) FROM document_chunks WHERE embedding IS NOT NULL")
    embedded_chunks = cur.fetchone()[0]
    
    remaining = total_chunks - embedded_chunks
    
    cur.close()
    conn.close()
    
    print(f"📊 Status:")
    print(f"   Total chunks: {total_chunks:,}")
    print(f"   Already embedded: {embedded_chunks:,}")
    print(f"   Remaining: {remaining:,}")
    
    return total_chunks, embedded_chunks, remaining

total_chunks, embedded_chunks, remaining_chunks = check_status()
# Out:
# 📊 Status:
#    Total chunks: 12,452
#    Already embedded: 0
#    Remaining: 12,452

# %%
# Generating embeddings for all chunks. This take about 10 minutes on an average CPU with the sleep option.
print(f"🔄 Generating embeddings for {remaining_chunks:,} chunks...")

conn = psycopg2.connect(DB_CONNECTION)
cur = conn.cursor()
processed = 0

while True:
    # Get next batch of chunks without embeddings
    cur.execute("""
        SELECT id, content FROM document_chunks 
        WHERE embedding IS NULL 
        ORDER BY id 
        LIMIT %s
    """, (BATCH_SIZE,))
    
    batch = cur.fetchall()
    if not batch:
        break
    
    # Extract texts and IDs
    chunk_ids = [row[0] for row in batch]
    texts = [row[1] for row in batch]
    
    # Generate embeddings
    try:
        embeddings = model.encode(texts, show_progress_bar=False, convert_to_numpy=True)
        
        # Update database
        for chunk_id, embedding in zip(chunk_ids, embeddings):
            # Convert numpy array to list for postgres
            embedding_list = embedding.tolist()
            cur.execute("""
                UPDATE document_chunks 
                SET embedding = %s 
                WHERE id = %s
            """, (embedding_list, chunk_id))
        
        conn.commit()
        processed += len(batch)
        if processed % 100 == 0:  # Print every 1600 chunks
            print(f"Processed {processed}/{remaining_chunks} chunks ({processed/remaining_chunks*100:.1f}%)")

        time.sleep(1) # Optional to cool my CPU
        
    except Exception as e:
        print(f"❌ Error processing batch: {e}")
        conn.rollback()
        break

cur.close()
conn.close()

print(f"✅ Generated embeddings for {processed:,} chunks!")

# Check final status
print("🔍 Final status check:")
total_chunks, embedded_chunks, remaining_chunks = check_status()

if remaining_chunks == 0:
    print("🎉 All chunks successfully embedded!")
else:
    print(f"⚠️  {remaining_chunks} chunks still need embeddings")
# Out:
# 🔄 Generating embeddings for 12,452 chunks...
# Processed 1600/12452 chunks (12.8%)
# Processed 3200/12452 chunks (25.7%)
# Processed 4800/12452 chunks (38.5%)
# Processed 6400/12452 chunks (51.4%)
# Processed 8000/12452 chunks (64.2%)
# Processed 9600/12452 chunks (77.1%)
# Processed 11200/12452 chunks (89.9%)
# ✅ Generated embeddings for 12,452 chunks!
# 🔍 Final status check:
# 📊 Status:
#    Total chunks: 12,452
#    Already embedded: 12,452
#    Remaining: 0
# 🎉 All chunks successfully embedded!

# %%
def test_similarity_search(query, top_k=5):
    """Test the similarity search functionality"""
    
    # Generate query embedding
    query_embedding = model.encode([query])[0].tolist()
    
    conn = psycopg2.connect(DB_CONNECTION)
    cur = conn.cursor()
    
    # FIXED: Cast the array to vector type
    cur.execute("""
        SELECT 
            title,
            content,
            1 - (embedding <=> %s::vector) as similarity,
            industries,
            country_codes,
            date::date,
            chunk_index
        FROM document_chunks 
        WHERE embedding IS NOT NULL
        ORDER BY embedding <=> %s::vector
        LIMIT %s
    """, (query_embedding, query_embedding, top_k))
    
    results = cur.fetchall()
    
    # Display results (rest stays the same)
    for i, (title, content, similarity, industries, countries, date, chunk_idx) in enumerate(results, 1):
        print(f"\n{i}. {title} (Chunk {chunk_idx})")
        print(f"   📊 Similarity: {similarity:.3f}")
        print(f"   📅 Date: {date or 'N/A'}")
        print(f"   🏭 Industries: {industries or 'N/A'}")
        print(f"   🌍 Countries: {countries or 'N/A'}")
        print(f"   📄 Content: {content}...")
        print("-" * 60)
    
    cur.close()
    conn.close()
    
    return results

# Test with various queries. I just opened a PDF, saw it refers to AI in banking and insurance 
test_queries = [
    "credit mutuel"
]

for query in test_queries:
    results = test_similarity_search(query, top_k=3)
    print("\n" + "="*100 + "\n")
# Out:
# 1. Crédit Mutuel Company report (Chunk 22)
#    📊 Similarity: 0.682
#    📅 Date: 2025-03-04
#    🏭 Industries: ['Finance and Insurance']
#    🌍 Countries: ['FR']
#    📄 Content: this ranking of the top 500 employers in France, Crédit Mutuel topped the list for the fifth consecutive year, illustrating its performance and proactive human resources policy. The award demonstrates once again that “Working in a bank without shareholders changes everything”! Survey conducted online, independently and anonymously, by the Statista institute among 20,000 employees of 2,100 employers with more than 5,000 employees, between 09/20/2023 and 10/17/2023.  15 ABOUT CRÉDIT MUTUEL GROUP Crédit Mutuel is a mutualist and cooperative banking group exclusively owned by its customermembers. It comprises 18 regional Crédit Mutuel federations and a national agricultural federation as well as numerous specialized subsidiaries, mainly offering financial and insurance services. Its main subsidiaries are CIC, Assurances du Crédit Mutuel, Suravenir, Targobank in Germany, Beobank in Belgium, Banque Européenne du Crédit Mutuel, Cofidis Group, La Française, Fortunéo and Monabanq. At December 31, 2024, Crédit Mutuel had 37.8 million customers, of which 9.2 million members, together with 87,105 employees....
# ------------------------------------------------------------
#
# 2. Crédit Mutuel Company report (Chunk 12)
#    📊 Similarity: 0.656
#    📅 Date: 2025-03-04
#    🏭 Industries: ['Finance and Insurance']
#    🌍 Countries: ['FR']
#    📄 Content: (LCR) stood at 167.8%, well above the required regulatory level of 100%. Crédit Mutuel held onto its very strong external ratings: A+ with a stable outlook at Standard & Poor’s.  8 VALUE CREATION AND SHARING: THE FOUNDATION OF OUR MUTUALIST VISION AND ACTIONS | GENERAL INTEREST AND CONTRIBUTION TO SOCIETY Crédit Mutuel group actively strives to achieve a lasting societal impact through tangible actions such as: - Crédit Mutuel Arkéa was the first French bank to be able to calculate its overall performance using a methodology that converts non-financial impacts into euros; - Crédit Mutuel Alliance Fédérale, which allocates 15% of its net income each year to projects with a social dividend; - Crédit Mutuel Maine-Anjou, Basse Normandie and Crédit Mutuel Océan, which have defined a raison d'être. In direct contact with local realities, the Group supports diversity and inclusion, fights against all forms of discrimination, defends the principles of gender equality and, more generally, equal opportunities, challenges to which all the Group's employees are committed on a daily basis. Crédit Mutuel believes in active engagement and staying true to its mutualist convictions, and as such takes an active role in putting solidarity into practice....
# ------------------------------------------------------------
#
# 3. Crédit Mutuel Company report (Chunk 1)
#    📊 Similarity: 0.627
#    📅 Date: 2025-03-04
#    🏭 Industries: ['Finance and Insurance']
#    🌍 Countries: ['FR']
#    📄 Content: innovation and commitment to the common good, notably through value sharing, are key factors for navigating this period of political and economic turbulence with resilience. Backed by the commitment of its 87,000 employees and nearly 20,000 elected representatives, serving its 37.8 million retail, professional and corporate customers and members in France and Europe, Crédit Mutuel group once again demonstrated its efficiency, with a cost/income ratio that improved significantly by 1.5 points to 57.7%. Crédit Mutuel group's financial solidity was fully confirmed with a CET1 ratio of 19.4%. 1 Net income attributable to the group  2 Daniel Baal, Chairman, Confédération Nationale du Crédit Mutuel: “Crédit Mutuel group’s results demonstrate the robustness and relevance of its decentralized and diversified banking and insurance model, which is proving to be a driver of growth and resilience, even in a complex economic and political environment. Our commitment enables us to ensure financial stability while enhancing collective utility. At the heart of our model, trust and solidarity are essential values for driving the transitions we are going through. The cooperative and mutualist group is firmly committed to supporting its members and customers - individuals, professionals, businesses, farmers and associations - at every key moment in their lives....
# ------------------------------------------------------------
#
# ====================================================================================================
